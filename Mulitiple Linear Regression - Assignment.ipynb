# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
Startups = pd.read_csv('I:\Assigment - Data Science\Muilti linear regression/50_Startups.csv')

# %%
Startups
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
Startups.describe(include = 'all')
# Out:
#             R&D Spend  Administration  Marketing Spend     State  \
# count       50.000000       50.000000        50.000000        50
# unique            NaN             NaN              NaN         3
# top               NaN             NaN              NaN  New York
# freq              NaN             NaN              NaN        17
# mean     73721.615600   121344.639600    211025.097800       NaN
# std      45902.256482    28017.802755    122290.310726       NaN
# min          0.000000    51283.140000         0.000000       NaN
# 25%      39936.370000   103730.875000    129300.132500       NaN
# 50%      73051.080000   122699.795000    212716.240000       NaN
# 75%     101602.800000   144842.180000    299469.085000       NaN
# max     165349.200000   182645.560000    471784.100000       NaN
#
#                Profit
# count       50.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean    112012.639200
# std      40306.180338
# ...

# %%
Startups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
Startups.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.set_style(style = 'darkgrid')
sns.pairplot(Startups)

# %%
data = Startups.copy()
data['State'] = data['State'].map({'New York': 2, 'California': 1,'Florida': 0})

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      2  192261.83
# 1   162597.70       151377.59        443898.53      1  191792.06
# 2   153441.51       101145.55        407934.54      0  191050.39
# 3   144372.41       118671.85        383199.62      2  182901.99
# 4   142107.34        91391.77        366168.42      0  166187.94
# 5   131876.90        99814.71        362861.36      2  156991.12
# 6   134615.46       147198.87        127716.82      1  156122.51
# 7   130298.13       145530.06        323876.68      0  155752.60
# 8   120542.52       148718.95        311613.29      2  152211.77
# 9   123334.88       108679.17        304981.62      1  149759.96
# 10  101913.08       110594.11        229160.95      0  146121.95
# 11  100671.96        91790.61        249744.55      1  144259.40
# 12   93863.75       127320.38        249839.44      0  141585.52
# ...

# %%
y = data['Profit']
x = data[['R&D Spend','Administration','Marketing Spend','State']]

# %%
x = sm.add_constant(x)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Thu, 01 Apr 2021   Prob (F-statistic):           8.49e-29
# Time:                        00:20:58   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
## From the Pair Plot their is a linear relationship between Marketing and R $ D so we will remove R and D and will se the correaltion

# %%
y = data['Profit']
x = data[['Administration','Marketing Spend','State']]

# %%
x = sm.add_constant(x)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.588
# Method:                 Least Squares   F-statistic:                     24.28
# Date:                Thu, 01 Apr 2021   Prob (F-statistic):           1.44e-09
# Time:                        00:20:59   Log-Likelihood:                -576.93
# No. Observations:                  50   AIC:                             1162.
# Df Residuals:                      46   BIC:                             1169.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
y = data['Profit']
x = data[['Administration','R&D Spend','State']]

# %%
sm.add_constant(x)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared (uncentered):                   0.984
# Model:                            OLS   Adj. R-squared (uncentered):              0.983
# Method:                 Least Squares   F-statistic:                              983.0
# Date:                Thu, 01 Apr 2021   Prob (F-statistic):                    2.18e-42
# Time:                        00:20:59   Log-Likelihood:                         -551.38
# No. Observations:                  50   AIC:                                      1109.
# Df Residuals:                      47   BIC:                                      1114.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
## without the variable Marketing Spend still we are getting the high value of R squared.

# %%
import pandas as pd

# %%
Toyoto = pd.read_csv('I:\Assigment - Data Science\Muilti linear regression/Toyoto_Corrola.csv')

# %%
Toyoto
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3     ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04     KM   HP  Doors  Cylinders  Gears  Weight
# 0            23  46986   90      3          4      5    1165
# ...

# %%
Toyoto.head(20)
# Out:
#     Id                                              Model  Price  Age_08_04  \
# 0    1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1    2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2    3     ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3    4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4    5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
# 5    6        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  12950         32
# 6    7     ÊTOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors  16900         27
# 7    8      TOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors  18600         30
# 8    9       ÊTOYOTA Corolla 1800 T SPORT VVT I 2/3-Doors  21500         27
# 9   10       ÊTOYOTA Corolla 1.9 D HATCHB TERRA 2/3-Doors  12950         23
# 10  11  TOYOTA Corolla 1.8 VVTL-i T-Sport 3-Drs 2/3-Doors  20950         25
# ...

# %%
Toyo = Toyoto.drop(['Id'],axis = 1)
Toyo
# Out:
#                                                   Model  Price  Age_08_04  \
# 0         TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1         TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2        ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3         TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4           TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
# ...                                                 ...    ...        ...
# 1431         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500         69
# 1432  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845         72
# 1433  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500         71
# 1434  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250         70
# 1435        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950         76
#
#          KM   HP  Doors  Cylinders  Gears  Weight
# ...

# %%
Toyo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Model      1436 non-null   object
#  1   Price      1436 non-null   int64
#  2   Age_08_04  1436 non-null   int64
#  3   KM         1436 non-null   int64
#  4   HP         1436 non-null   int64
#  5   Doors      1436 non-null   int64
#  6   Cylinders  1436 non-null   int64
#  7   Gears      1436 non-null   int64
#  8   Weight     1436 non-null   int64
# dtypes: int64(8), object(1)
# memory usage: 101.1+ KB

# %%
Toyo.describe(include = 'all')
# Out:
#                                                     Model         Price  \
# count                                                1436   1436.000000
# unique                                                372           NaN
# top     TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-...           NaN
# freq                                                  107           NaN
# mean                                                  NaN  10730.824513
# std                                                   NaN   3626.964585
# min                                                   NaN   4350.000000
# 25%                                                   NaN   8450.000000
# 50%                                                   NaN   9900.000000
# 75%                                                   NaN  11950.000000
# max                                                   NaN  32500.000000
#
#           Age_08_04             KM           HP        Doors  Cylinders  \
# ...

# %%
Toyo.corr()
# Out:
#               Price  Age_08_04        KM        HP     Doors  Cylinders  \
# Price      1.000000  -0.876590 -0.569960  0.314990  0.185326        NaN
# Age_08_04 -0.876590   1.000000  0.505672 -0.156622 -0.148359        NaN
# KM        -0.569960   0.505672  1.000000 -0.333538 -0.036197        NaN
# HP         0.314990  -0.156622 -0.333538  1.000000  0.092424        NaN
# Doors      0.185326  -0.148359 -0.036197  0.092424  1.000000        NaN
# Cylinders       NaN        NaN       NaN       NaN       NaN        NaN
# Gears      0.063104  -0.005364  0.015023  0.209477 -0.160141        NaN
# Weight     0.581198  -0.470253 -0.028598  0.089614  0.302618        NaN
#
#               Gears    Weight
# Price      0.063104  0.581198
# Age_08_04 -0.005364 -0.470253
# KM         0.015023 -0.028598
# HP         0.209477  0.089614
# Doors     -0.160141  0.302618
# Cylinders       NaN       NaN
# Gears      1.000000  0.020613
# Weight     0.020613  1.000000

# %%
sns.set_style(style = 'darkgrid')
sns.pairplot(Toyo)

# %%
Toyo= Toyoto.drop_duplicates()
Toyo.shape
# Out:
# (1436, 10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
model = smf.ols('Price ~ Age_08_04 + KM + Weight', data = Toyo).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     2665.
# Date:                Thu, 01 Apr 2021   Prob (F-statistic):               0.00
# Time:                        00:22:11   Log-Likelihood:                -12454.
# No. Observations:                1436   AIC:                         2.492e+04
# Df Residuals:                    1432   BIC:                         2.494e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1880.3356    962.718     -1.953      0.051   -3768.825       8.153
# ...

# %%
model = smf.ols('Price ~ Cylinders + Doors + HP+ Gears',data = Toyo).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.125
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     67.90
# Date:                Thu, 01 Apr 2021   Prob (F-statistic):           4.73e-41
# Time:                        00:26:46   Log-Likelihood:                -13711.
# No. Observations:                1436   AIC:                         2.743e+04
# Df Residuals:                    1432   BIC:                         2.745e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -97.3378    147.914     -0.658      0.511    -387.490     192.814
# ...

# %% [raw]
# ## Theses three variable are not able to explain the model as the R square value is very less hence we will not consider the Cylinder ,
# HP, Doors and Gears in our Model parameters

# %%
model = smf.ols('Price ~ Age_08_04 ', data = Toyo).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     4758.
# Date:                Thu, 01 Apr 2021   Prob (F-statistic):               0.00
# Time:                        00:31:01   Log-Likelihood:                -12756.
# No. Observations:                1436   AIC:                         2.552e+04
# Df Residuals:                    1434   BIC:                         2.553e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.029e+04    146.097    138.908      0.000       2e+04    2.06e+04
# ...

# %%
model = smf.ols('Price~ KM',data = Toyo).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.325
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     690.0
# Date:                Thu, 01 Apr 2021   Prob (F-statistic):          1.76e-124
# Time:                        00:31:53   Log-Likelihood:                -13525.
# No. Observations:                1436   AIC:                         2.705e+04
# Df Residuals:                    1434   BIC:                         2.706e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.451e+04    163.915     88.510      0.000    1.42e+04    1.48e+04
# ...

# %%
model = smf.ols('Price~Weight',data = Toyo).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     731.5
# Date:                Thu, 01 Apr 2021   Prob (F-statistic):          1.63e-130
# Time:                        00:32:56   Log-Likelihood:                -13511.
# No. Observations:                1436   AIC:                         2.703e+04
# Df Residuals:                    1434   BIC:                         2.704e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.222e+04   1589.807    -20.264      0.000   -3.53e+04   -2.91e+04
# ...

# %%
## these three variable can explain the model parameters so we will use Age, Km and Weight to predict our Model.
